# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# #Genera un dataframe y muéstralo

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #Mostrar por pantalla las filas impares del DataFrame

# %%
start=time.time()
df[1::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 5              6         0       3
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 881          882         0       3
# 883          884         0       2
# 885          886         0       3
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #Mostrar por pantalla las filas 10 y 11.

# %%
df[9:11]
# Out:
#     PassengerId  Survived  Pclass                                 Name  \
# 9            10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3      Sandstrom, Miss. Marguerite Rut
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S

# %% [markdown]
# #Muestra aquellas filas de los pasajeros que tengan el campo Embarked a nulo y muestra los resultados del fichero tras esta operación.

# %%
start=time.time()
df[df['Embarked'].isna()]
print(time.time()-start)
# Out:
# 0.0019745826721191406

# %% [markdown]
# #Mostrar por pantalla los nombres de las personas que iban en primera clase ordenadas alfabéticamente.

# %%
primera_clase=df[df['Pclass']==1]
primera_clase.sort_values('Name')
# Out:
#      PassengerId  Survived  Pclass  \
# 730          731         1       1
# 305          306         1       1
# 297          298         0       1
# 498          499         0       1
# 460          461         1       1
# ..           ...       ...     ...
# 155          156         0       1
# 351          352         0       1
# 55            56         1       1
# 555          556         0       1
# 325          326         1       1
#
#                                                 Name     Sex    Age  SibSp  \
# 730                    Allen, Miss. Elisabeth Walton  female  29.00      0
# 305                   Allison, Master. Hudson Trevor    male   0.92      1
# 297                     Allison, Miss. Helen Loraine  female   2.00      1
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# 460                              Anderson, Mr. Harry    male  48.00      0
# ..                                               ...     ...    ...    ...
# ...

# %% [markdown]
# #Mostrar por pantalla el porcentaje de personas que sobrevivieron y murieron.

# %%
(len(df[df['Survived']==1])/df['Survived'].count()*100).round(2)
# Out:
# 38.38

# %% [markdown]
# #Mostrar por pantalla el porcentaje de personas que sobrevivieron en cada clase.

# %%
clase_1=df[df['Pclass']==1]
(len(clase_1[clase_1['Survived']==1])/clase_1['Survived'].count()*100).round(2)
# Out:
# 62.96

# %%
clase_2=df[df['Pclass']==2]
(len(clase_2[clase_2['Survived']==1])/clase_2['Survived'].count()*100).round(2)
# Out:
# 47.28

# %%
clase_3=df[df['Pclass']==3]
(len(clase_3[clase_3['Survived']==1])/clase_3['Survived'].count()*100).round(2)
# Out:
# 24.24

# %% [markdown]
# #Eliminar del DataFrame los pasajeros con edad desconocida.

# %%
df=df.dropna(subset = ['Age'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #Mostrar por pantalla la edad media de las mujeres que viajaban en cada clase.

# %%
mujeres=df[df['Sex']=='female']
mujeres.groupby('Pclass')['Age'].mean().round()
# Out:
# Pclass
# 1    35.0
# 2    29.0
# 3    22.0
# Name: Age, dtype: float64

# %% [markdown]
# #Añadir una nueva columna booleana para ver si el pasajero era menor de edad o no.

# %%
df['Minor']=np.where(df['Age']<18,True,False)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %% [markdown]
# #Mostrar por pantalla el porcentaje de menores y mayores de edad que sobrevivieron en cada clase.

# %%
df.groupby(['Minor','Pclass'])['Survived'].mean()*100
# Out:
# Minor  Pclass
# False  1         63.793103
#        2         41.333333
#        3         20.216606
# True   1         91.666667
#        2         91.304348
#        3         37.179487
# Name: Survived, dtype: float64
