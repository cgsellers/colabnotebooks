# %%
import pymongo
conexion = pymongo.MongoClient('mongodb+srv://CarlosG:carlosgbda@cluster0.0sw2log.mongodb.net/?retryWrites=true&w=majority')
db=conexion.test

# %%
print(conexion.list_database_names())
# Out:
# ['sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_guides', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']
