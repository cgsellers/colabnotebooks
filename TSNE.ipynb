# %%
# Importo librerías
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Cargo un dataset de clasificacion
dataset = load_iris()
X = dataset.data
Y = dataset.target
print(u'El número total de variables de este dataset es: {}'.format(X.shape[1]))
# Out:
# El número total de variables de este dataset es: 4

# %%
X.shape
# Out:
# (150, 4)

# %%
# Escalo las variables antes de introducirlas al PCA
scaler = StandardScaler()
X_escaladas = scaler.fit_transform(X)

# %%
from sklearn.manifold import TSNE

# %%
modelotsne = TSNE(n_components=3, learning_rate='auto' ,init='random', perplexity=3)

# %%
xmod=modelotsne.fit_transform(X_escaladas)

# %%
xmod.shape
# Out:
# (150, 3)
