# %%
import pandas as pd

# %%
url1 = ("https://es.wikipedia.org/wiki/Energ%C3%ADa")

# %%
tabla1 = pd.read_html(url1)

# %%
tabla1
# Out:
# [                              Nombre     Unidad Equivalencia en julios
#  0                            Caloría        cal                  41868
#  1                           Frigoría         fg                  41868
#  2                             Termia         th              4 185 500
#  3                     Kilovatio hora        kWh              3 600 000
#  4                     Caloría grande        Cal                  41855
#  5   Tonelada equivalente de petróleo        Tep         41 840 000 000
#  6     Tonelada equivalente de carbón        Tec         29 300 000 000
#  7                     Electronvoltio         eV    1,602176462 × 10-19
#  8               British Thermal Unit  BTU o BTu              105505585
#  9     Caballo de vapor por hora[16]​        CVh     3,777154675 × 10-7
#  10                             Ergio        erg               1 × 10-7
#  11        Pie por libra (Foot pound)    ft × lb              135581795
# ...

# %%
url2=("https://es.wikipedia.org/wiki/Anexo:Episodios_de_Better_Call_Saul")

# %%
tabla2 = pd.read_html(url2)

# %%
tabla2[5].shape
# Out:
# (10, 7)

# %%
archivo = '/content/autores.csv'

# %%
df1=pd.read_csv(archivo)
df1.info
# Out:
# <bound method DataFrame.info of     Nombre  Edad     CP  Altura
# 0  Antonio    28   6000     174
# 1     José    23  10000     165
# 2      Ana    18  10254     195
# 3     Ines    30   6480     180
# 4    Pedro    78  10121     168>

# %%
df1.size
# Out:
# 20

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nombre  5 non-null      object
#  1   Edad    5 non-null      int64
#  2   CP      5 non-null      int64
#  3   Altura  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 288.0+ bytes
