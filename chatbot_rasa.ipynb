# %%
# !pip install rasa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasa
#   Downloading rasa-3.5.4-py3-none-any.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.19.2 in /usr/local/lib/python3.9/dist-packages (from rasa) (1.22.4)
# Collecting SQLAlchemy<1.5.0,>=1.4.0
#   Downloading SQLAlchemy-1.4.47-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 56.8 MB/s eta 0:00:00
# Collecting absl-py<1.4,>=0.9
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 15.9 MB/s eta 0:00:00
# Collecting attrs<22.2,>=19.3
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from rasa) (1.0.0)
# Collecting psycopg2-binary<2.10.0,>=2.8.2
#   Downloading psycopg2_binary-2.9.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 63.3 MB/s eta 0:00:00
# Collecting rasa-sdk<3.6.0,>=3.5.0
#   Downloading rasa_sdk-3.5.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 5.1 MB/s eta 0:00:00
# Collecting colorhash<1.3.0,>=1.0.2
#   Downloading colorhash-1.2.1-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: jsonpickle<3.1,>=1.3 in /usr/local/lib/python3.9/dist-packages (from rasa) (3.0.1)
# Collecting ujson<6.0,>=1.35
#   Downloading ujson-5.7.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 6.7 MB/s eta 0:00:00
# Collecting packaging<21.0,>=20.0
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.9/dist-packages (from rasa) (2.8.2)
# Collecting scipy<1.9.0,>=1.4.1
#   Downloading scipy-1.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 14.0 MB/s eta 0:00:00
# Collecting tensorflow-text==2.11.0
#   Downloading tensorflow_text-2.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 48.4 MB/s eta 0:00:00
# Collecting tensorflow_hub<0.13.0,>=0.12.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0,>=2.23 in /usr/local/lib/python3.9/dist-packages (from rasa) (2.27.1)
# Collecting ruamel.yaml<0.18.0,>=0.16.5
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 14.7 MB/s eta 0:00:00
# Collecting colorclass<2.3,>=2.2
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Collecting sanic-cors<2.1.0,>=2.0.0
#   Downloading Sanic_Cors-2.0.1-py2.py3-none-any.whl (17 kB)
# Collecting terminaltables<3.2.0,>=3.1.0
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting python-socketio<6,>=4.4
#   Downloading python_socketio-5.8.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema<4.18,>=3.2 in /usr/local/lib/python3.9/dist-packages (from rasa) (4.3.3)
# Collecting sanic-jwt<2.0.0,>=1.6.0
#   Downloading sanic_jwt-1.8.0-py3-none-any.whl (23 kB)
# Collecting aiogram<2.26
#   Downloading aiogram-2.25.1-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 27.0 MB/s eta 0:00:00
# Collecting tarsafe<0.0.4,>=0.0.3
#   Downloading tarsafe-0.0.3-py3-none-any.whl (5.0 kB)
# Collecting aiohttp!=3.7.4.post0,<3.9,>=3.6
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.6 MB/s eta 0:00:00
# Collecting webexteamssdk<1.7.0,>=1.1.1
#   Downloading webexteamssdk-1.6.1-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 16.5 MB/s eta 0:00:00
# Collecting tensorflow==2.11.0
#   Downloading tensorflow-2.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<2.3,>=1.2 in /usr/local/lib/python3.9/dist-packages (from rasa) (2.2.1)
# Collecting sanic-routing<0.8.0,>=0.7.2
#   Downloading sanic_routing-0.7.2-py3-none-any.whl (23 kB)
# Collecting dask==2022.10.2
#   Downloading dask-2022.10.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.2 MB/s eta 0:00:00
# Requirement already satisfied: CacheControl<0.13.0,>=0.12.9 in /usr/local/lib/python3.9/dist-packages (from rasa) (0.12.11)
# Collecting PyJWT[crypto]<3.0.0,>=2.0.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting matplotlib<3.6,>=3.1
#   Downloading matplotlib-3.5.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 91.6 MB/s eta 0:00:00
# Collecting tensorflow-addons<0.20,>=0.18
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from rasa) (4.5.0)
# Collecting boto3<2.0,>=1.12
#   Downloading boto3-1.26.112-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 15.9 MB/s eta 0:00:00
# Collecting fbmessenger<6.1.0,>=6.0.0
#   Downloading fbmessenger-6.0.0-py2.py3-none-any.whl (11 kB)
# Collecting sklearn-crfsuite<0.4,>=0.3
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Collecting pykwalify<1.9,>=1.7
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 13.2 MB/s eta 0:00:00
# Collecting twilio<7.15,>=6.26
#   Downloading twilio-7.14.2-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.8 MB/s eta 0:00:00
# Collecting aio-pika<8.2.4,>=6.7.1
#   Downloading aio_pika-8.2.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from rasa) (67.6.1)
# Collecting prompt-toolkit<3.0.29,>=3.0
#   Downloading prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.2/380.2 kB 39.9 MB/s eta 0:00:00
# Collecting mattermostwrapper<2.3,>=2.2
#   Downloading mattermostwrapper-2.2.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting typing-utils<0.2.0,>=0.1.0
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting python-engineio!=5.0.0,<6,>=4
#   Downloading python_engineio-4.4.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.0 MB/s eta 0:00:00
# Collecting sentry-sdk<1.15.0,>=0.17.0
#   Downloading sentry_sdk-1.14.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 21.7 MB/s eta 0:00:00
# Collecting questionary<1.11.0,>=1.5.1
#   Downloading questionary-1.10.0-py3-none-any.whl (31 kB)
# Collecting sanic<21.13,>=21.12
#   Downloading sanic-21.12.2-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 18.7 MB/s eta 0:00:00
# Collecting scikit-learn<1.2,>=0.22
#   Downloading scikit_learn-1.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 44.2 MB/s eta 0:00:00
# Collecting apscheduler<3.10,>=3.6
#   Downloading APScheduler-3.9.1.post1-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib<1.3.0,>=0.15.1 in /usr/local/lib/python3.9/dist-packages (from rasa) (1.2.0)
# Collecting randomname<0.2.0,>=0.1.5
#   Downloading randomname-0.1.5.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm<5.0,>=4.31 in /usr/local/lib/python3.9/dist-packages (from rasa) (4.65.0)
# Collecting pydantic<1.10.3
#   Downloading pydantic-1.10.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 87.6 MB/s eta 0:00:00
# Collecting confluent-kafka<2.0.0,>=1.9.2
#   Downloading confluent_kafka-1.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.8 MB/s eta 0:00:00
# Collecting pymongo[srv,tls]<3.11,>=3.8
#   Downloading pymongo-3.10.1.tar.gz (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.9/715.9 kB 55.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rocketchat_API<1.29.0,>=0.6.31
#   Downloading rocketchat_API-1.28.1-py3-none-any.whl (20 kB)
# Collecting networkx<2.7,>=2.4
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 81.3 MB/s eta 0:00:00
# Collecting slack-sdk<4.0.0,>=3.19.2
#   Downloading slack_sdk-3.21.1-py2.py3-none-any.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.5/276.5 kB 31.2 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.1 MB/s eta 0:00:00
# Collecting coloredlogs<16,>=10
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pydot<1.5,>=1.4 in /usr/local/lib/python3.9/dist-packages (from rasa) (1.4.2)
# Requirement already satisfied: google-auth<3 in /usr/local/lib/python3.9/dist-packages (from rasa) (2.17.2)
# Collecting redis<5.0,>=4.5.3
#   Downloading redis-4.5.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: regex<2022.11,>=2020.6 in /usr/local/lib/python3.9/dist-packages (from rasa) (2022.10.31)
# Requirement already satisfied: pytz<2023.0,>=2019.1 in /usr/local/lib/python3.9/dist-packages (from rasa) (2022.7.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from dask==2022.10.2->rasa) (8.1.3)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.9/dist-packages (from dask==2022.10.2->rasa) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from dask==2022.10.2->rasa) (0.12.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from dask==2022.10.2->rasa) (6.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from dask==2022.10.2->rasa) (2023.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (16.0.0)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 60.1 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (2.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (23.3.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (1.16.0)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 71.6 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (1.53.0)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 32.5 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (0.32.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.0->rasa) (1.6.3)
# Collecting aiormq~=6.4.0
#   Downloading aiormq-6.4.2-py3-none-any.whl (34 kB)
# Collecting yarl
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 18.9 MB/s eta 0:00:00
# Collecting Babel<2.10.0,>=2.9.1
#   Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 70.7 MB/s eta 0:00:00
# Collecting magic-filter>=1.0.9
#   Downloading magic_filter-1.0.9-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.9/dist-packages (from aiogram<2.26->rasa) (2022.12.7)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in /usr/local/lib/python3.9/dist-packages (from apscheduler<3.10,>=3.6->rasa) (4.3)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 12.3 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.112
#   Downloading botocore-1.29.112-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 95.1 MB/s eta 0:00:00
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from CacheControl<0.13.0,>=0.12.9->rasa) (1.0.5)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3->rasa) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3->rasa) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3->rasa) (0.2.8)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema<4.18,>=3.2->rasa) (0.19.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.6,>=3.1->rasa) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.6,>=3.1->rasa) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.6,>=3.1->rasa) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.6,>=3.1->rasa) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<3.6,>=3.1->rasa) (3.0.9)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<3.0.29,>=3.0->rasa) (0.2.6)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (40.0.1)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dnspython<2.0.0,>=1.16.0
#   Downloading dnspython-1.16.0-py2.py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 kB 19.9 MB/s eta 0:00:00
# Collecting bidict>=0.21.0
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.23->rasa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.23->rasa) (1.26.15)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.4/519.4 kB 49.9 MB/s eta 0:00:00
# Collecting aiofiles>=0.6.0
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.7/174.7 kB 19.8 MB/s eta 0:00:00
# Collecting uvloop>=0.5.3
#   Downloading uvloop-0.17.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 85.9 MB/s eta 0:00:00
# Collecting httptools>=0.0.10
#   Downloading httptools-0.5.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 kB 43.5 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<1.2,>=0.22->rasa) (3.1.0)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.4 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa) (0.8.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from SQLAlchemy<1.5.0,>=1.4.0->rasa) (2.0.2)
# Collecting typeguard>=2.7
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (0.18.3)
# Collecting pamqp==3.2.1
#   Downloading pamqp-3.2.1-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow==2.11.0->rasa) (0.40.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (1.15.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.9/dist-packages (from partd>=0.3.10->dask==2022.10.2->rasa) (1.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3->rasa) (0.4.8)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.0->rasa) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.0->rasa) (3.4.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 78.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.0->rasa) (1.8.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons<0.20,>=0.18->rasa) (6.3.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal!=3.*,>=2.0->apscheduler<3.10,>=3.6->rasa) (0.1.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (2.21)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.0->rasa) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->typeguard>=2.7->tensorflow-addons<0.20,>=0.18->rasa) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow==2.11.0->rasa) (2.1.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal!=3.*,>=2.0->apscheduler<3.10,>=3.6->rasa) (2023.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.0->rasa) (3.2.2)
# Building wheels for collected packages: mattermostwrapper, randomname, docopt, fire, pymongo
#   Building wheel for mattermostwrapper (setup.py) ... done
#   Created wheel for mattermostwrapper: filename=mattermostwrapper-2.2-py3-none-any.whl size=2464 sha256=17cef34f279eef76a28cb5e90535f47b0d8bb4890146fa56e0b89f271df99f44
#   Stored in directory: /root/.cache/pip/wheels/a1/0c/8d/2a8c86685b83e227bbf8ac97eca476f45b81de2ca7b5eb97ad
#   Building wheel for randomname (setup.py) ... done
#   Created wheel for randomname: filename=randomname-0.1.5-py3-none-any.whl size=58825 sha256=c10eafd0e2df6894ce17c7f359b9cfd96126998410350b85af9e3273614c8b19
#   Stored in directory: /root/.cache/pip/wheels/b3/1d/bc/4a7f077fd33bd14be2a75ddaf968c86c1e96cca81ba1ad68a0
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=13d13ae864db556ee3da6686bee5361a486ef293f283588300911fcf06f1a2e0
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=ad2645ec95e008abcc49cf677fbdce5622818f667baa18828482caa580801b97
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.10.1-cp39-cp39-linux_x86_64.whl size=470874 sha256=2e543fe1bfadcf2d3eb002e313d1951202f61807e9b29c90c6d1ac931eed9e2b
#   Stored in directory: /root/.cache/pip/wheels/8c/a6/78/a2b5a407b666d5261fd6a2138762da57a65e144dc3c7d2f7bd
# Successfully built mattermostwrapper randomname docopt fire pymongo
# Installing collected packages: sanic-routing, python-crfsuite, docopt, confluent-kafka, websockets, uvloop, ujson, typing-utils, terminaltables, tensorflow-estimator, tensorboard-data-server, tarsafe, SQLAlchemy, slack-sdk, sklearn-crfsuite, sentry-sdk, scipy, ruamel.yaml.clib, python-engineio, pymongo, PyJWT, pydantic, psycopg2-binary, protobuf, prompt-toolkit, pamqp, packaging, networkx, multidict, magic-filter, keras, jmespath, humanfriendly, httptools, frozenlist, fire, dnspython, colorhash, colorclass, bidict, Babel, attrs, async-timeout, aiofiles, absl-py, yarl, typeguard, twilio, tensorflow_hub, scikit-learn, sanic-jwt, sanic, ruamel.yaml, rocketchat_API, requests-toolbelt, redis, randomname, questionary, python-socketio, mattermostwrapper, matplotlib, fbmessenger, dask, coloredlogs, botocore, aiosignal, webexteamssdk, tensorflow-addons, sanic-cors, s3transfer, pykwalify, google-auth-oauthlib, apscheduler, aiormq, aiohttp, tensorboard, rasa-sdk, boto3, aiogram, aio-pika, tensorflow, tensorflow-text, rasa
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.9
#     Uninstalling SQLAlchemy-2.0.9:
#       Successfully uninstalled SQLAlchemy-2.0.9
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.7
#     Uninstalling pydantic-1.10.7:
#       Successfully uninstalled pydantic-1.10.7
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.38
#     Uninstalling prompt-toolkit-3.0.38:
#       Successfully uninstalled prompt-toolkit-3.0.38
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: Babel
#     Found existing installation: Babel 2.12.1
#     Uninstalling Babel-2.12.1:
#       Successfully uninstalled Babel-2.12.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.2.0
#     Uninstalling attrs-22.2.0:
#       Successfully uninstalled attrs-22.2.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: tensorflow_hub
#     Found existing installation: tensorflow-hub 0.13.0
#     Uninstalling tensorflow-hub-0.13.0:
#       Successfully uninstalled tensorflow-hub-0.13.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: dask
#     Found existing installation: dask 2022.12.1
#     Uninstalling dask-2022.12.1:
#       Successfully uninstalled dask-2022.12.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.1
#     Uninstalling tensorboard-2.12.1:
#       Successfully uninstalled tensorboard-2.12.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# statsmodels 0.13.5 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# distributed 2022.12.1 requires dask==2022.12.1, but you have dask 2022.10.2 which is incompatible.
# Successfully installed Babel-2.9.1 PyJWT-2.6.0 SQLAlchemy-1.4.47 absl-py-1.3.0 aio-pika-8.2.3 aiofiles-23.1.0 aiogram-2.25.1 aiohttp-3.8.4 aiormq-6.4.2 aiosignal-1.3.1 apscheduler-3.9.1.post1 async-timeout-4.0.2 attrs-22.1.0 bidict-0.22.1 boto3-1.26.112 botocore-1.29.112 colorclass-2.2.2 coloredlogs-15.0.1 colorhash-1.2.1 confluent-kafka-1.9.2 dask-2022.10.2 dnspython-1.16.0 docopt-0.6.2 fbmessenger-6.0.0 fire-0.5.0 frozenlist-1.3.3 google-auth-oauthlib-0.4.6 httptools-0.5.0 humanfriendly-10.0 jmespath-1.0.1 keras-2.11.0 magic-filter-1.0.9 matplotlib-3.5.3 mattermostwrapper-2.2 multidict-5.2.0 networkx-2.6.3 packaging-20.9 pamqp-3.2.1 prompt-toolkit-3.0.28 protobuf-3.19.6 psycopg2-binary-2.9.6 pydantic-1.10.2 pykwalify-1.8.0 pymongo-3.10.1 python-crfsuite-0.9.9 python-engineio-4.4.0 python-socketio-5.8.0 questionary-1.10.0 randomname-0.1.5 rasa-3.5.4 rasa-sdk-3.5.1 redis-4.5.4 requests-toolbelt-0.10.1 rocketchat_API-1.28.1 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7 s3transfer-0.6.0 sanic-21.12.2 sanic-cors-2.0.1 sanic-jwt-1.8.0 sanic-routing-0.7.2 scikit-learn-1.1.3 scipy-1.8.1 sentry-sdk-1.14.0 sklearn-crfsuite-0.3.6 slack-sdk-3.21.1 tarsafe-0.0.3 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorflow-2.11.0 tensorflow-addons-0.19.0 tensorflow-estimator-2.11.0 tensorflow-text-2.11.0 tensorflow_hub-0.12.0 terminaltables-3.1.10 twilio-7.14.2 typeguard-3.0.2 typing-utils-0.1.0 ujson-5.7.0 uvloop-0.17.0 webexteamssdk-1.6.1 websockets-10.4 yarl-1.8.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir my_chatbot_project
# %cd my_chatbot_project
# !rasa init --no-prompt
# Out:
# /content/my_chatbot_project
# /bin/bash: rasa: command not found
# /content/my_chatbot_project/my_chatbot_project
# /usr/local/lib/python3.9/dist-packages/rasa/core/tracker_store.py:1048: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# (0lqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqk(B
# (0x(B Rasa Open Source reports anonymous usage telemetry to help improve the product (0x(B
# (0x(B for all its users.                                                             (0x(B
# (0x(B                                                                                (0x(B
# (0x(B If you'd like to opt-out, you can use `rasa telemetry disable`.                (0x(B
# (0x(B To learn more, check out https://rasa.com/docs/rasa/telemetry/telemetry.       (0x(B
# (0mqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqj(B
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.logging')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('ruamel.yaml')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# Welcome to Rasa! 🤖
#
# To get started quickly, an initial project will be created.
# If you need some help, check out the documentation at https://rasa.com/docs/rasa.
#
# Created project directory at '/content/my_chatbot_project/my_chatbot_project'.
# Finished creating project structure.
# Training an initial model...
# 2023-04-13 18:12:55 INFO     numexpr.utils  - NumExpr defaulting to 2 threads.
# The configuration for pipeline and policies was chosen automatically. It was written into the config file at 'config.yml'.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Starting to train component 'RegexFeaturizer'.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Finished training component 'RegexFeaturizer'.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Starting to train component 'LexicalSyntacticFeaturizer'.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Finished training component 'LexicalSyntacticFeaturizer'.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Starting to train component 'CountVectorsFeaturizer'.
# 2023-04-13 18:12:59 INFO     rasa.nlu.featurizers.sparse_featurizer.count_vectors_featurizer  - 80 vocabulary items were created for text attribute.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Finished training component 'CountVectorsFeaturizer'.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Starting to train component 'CountVectorsFeaturizer'.
# 2023-04-13 18:12:59 INFO     rasa.nlu.featurizers.sparse_featurizer.count_vectors_featurizer  - 697 vocabulary items were created for text attribute.
# 2023-04-13 18:12:59 INFO     rasa.engine.training.hooks  - Finished training component 'CountVectorsFeaturizer'.
# 2023-04-13 18:13:00 INFO     rasa.engine.training.hooks  - Starting to train component 'DIETClassifier'.
# Epochs: 100% 100/100 [00:50<00:00,  1.96it/s, t_loss=1.15, i_acc=1]
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Finished training component 'DIETClassifier'.
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Starting to train component 'EntitySynonymMapper'.
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Finished training component 'EntitySynonymMapper'.
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Starting to train component 'ResponseSelector'.
# 2023-04-13 18:13:52 INFO     rasa.nlu.selectors.response_selector  - Retrieval intent parameter was left to its default value. This response selector will be trained on training examples combining all retrieval intents.
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Finished training component 'ResponseSelector'.
# Processed story blocks: 100% 3/3 [00:00<00:00, 2438.55it/s, # trackers=1]
# Processed story blocks: 100% 3/3 [00:00<00:00, 1118.98it/s, # trackers=3]
# Processed story blocks: 100% 3/3 [00:00<00:00, 187.28it/s, # trackers=12]
# Processed story blocks: 100% 3/3 [00:00<00:00, 67.64it/s, # trackers=39]
# Processed rules: 100% 2/2 [00:00<00:00, 3631.43it/s, # trackers=1]
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Starting to train component 'MemoizationPolicy'.
# Processed trackers: 100% 3/3 [00:00<00:00, 2059.40it/s, # action=12]
# Processed actions: 12it [00:00, 7538.06it/s, # examples=12]
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Finished training component 'MemoizationPolicy'.
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Starting to train component 'RulePolicy'.
# Processed trackers: 100% 2/2 [00:00<00:00, 1556.04it/s, # action=5]
# Processed actions: 5it [00:00, 13197.94it/s, # examples=4]
# Processed trackers: 100% 3/3 [00:00<00:00, 1722.51it/s, # action=12]
# Processed trackers: 100% 2/2 [00:00<00:00, 1822.82it/s]
# Processed trackers: 100% 5/5 [00:00<00:00, 1429.75it/s]
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Finished training component 'RulePolicy'.
# 2023-04-13 18:13:52 INFO     rasa.engine.training.hooks  - Starting to train component 'TEDPolicy'.
# Processed trackers: 100% 120/120 [00:00<00:00, 2284.34it/s, # action=30]
# Epochs: 100% 100/100 [00:24<00:00,  4.10it/s, t_loss=5.4, loss=5.24, acc=1]
# 2023-04-13 18:14:20 INFO     rasa.engine.training.hooks  - Finished training component 'TEDPolicy'.
# 2023-04-13 18:14:20 INFO     rasa.engine.training.hooks  - Starting to train component 'UnexpecTEDIntentPolicy'.
# 2023-04-13 18:14:20 WARNING  rasa.shared.utils.common  - The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Processed trackers: 100% 120/120 [00:00<00:00, 3408.46it/s, # intent=12]
# Epochs: 100% 100/100 [00:22<00:00,  4.37it/s, t_loss=0.127, loss=0.0137, acc=1]
# 2023-04-13 18:14:48 INFO     rasa.engine.training.hooks  - Finished training component 'UnexpecTEDIntentPolicy'.
# Your Rasa model is trained and saved at 'models/20230413-181258-flush-inversion.tar.gz'.
# If you want to speak to the assistant, run 'rasa shell' at any time inside the project directory.
