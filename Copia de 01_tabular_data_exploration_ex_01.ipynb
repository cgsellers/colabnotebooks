# %% [markdown]
# # 📝 Exercise M1.01

# %% [markdown]
# Imagine we are interested in **predicting penguins species** based on two of their
# body measurements: `culmen length` and `culmen depth`. First we want to do some
# data exploration to get a feel for the data.
#
# ❓ What are the features? What is the target?

# %% [markdown]
# The data is located in `https://github.com/INRIA/scikit-learn-mooc/raw/main/datasets/penguins_classification.csv`, load it with
# `pandas` into a `DataFrame`.

# %%
# Write your code here.
import pandas as pd

# %%
df=pd.read_csv("https://github.com/INRIA/scikit-learn-mooc/raw/main/datasets/penguins_classification.csv")
df
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)    Species
# 0                  39.1               18.7     Adelie
# 1                  39.5               17.4     Adelie
# 2                  40.3               18.0     Adelie
# 3                  36.7               19.3     Adelie
# 4                  39.3               20.6     Adelie
# ..                  ...                ...        ...
# 337                55.8               19.8  Chinstrap
# 338                43.5               18.1  Chinstrap
# 339                49.6               18.2  Chinstrap
# 340                50.8               19.0  Chinstrap
# 341                50.2               18.7  Chinstrap
#
# [342 rows x 3 columns]

# %% [markdown]
# Show a few samples of the data.
#
# ❓ How many features are numerical? How many features are categorical?

# %%
df.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Culmen Length (mm)  342 non-null    float64
#  1   Culmen Depth (mm)   342 non-null    float64
#  2   Species             342 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 8.1+ KB

# %% [markdown]
# ❓ What are the different penguins species available in the dataset and how many
# samples of each species are there? Hint: select the right column and use the
# [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
# method.

# %%
df['Species'].value_counts()
# Out:
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: Species, dtype: int64

# %% [markdown]
# ❓ Plot histograms for the numerical features

# %%
# Write your code here.
import seaborn as srs

# %%
srs.histplot(df['Culmen Length (mm)'])

# %%
srs.histplot(df['Culmen Depth (mm)'])

# %% [markdown]
# ❓ Show features distribution for each class. Hint: use
# [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
# Write your code here.
srs.pairplot(df,hue="Species")

# %% [markdown]
# Looking at these distributions, how hard do you think it will be to classify
# the penguins only using `"culmen depth"` and `"culmen length"`?

# %% [markdown]
# No, porque la especie Chinstrap se encuentra en las mismas medidas de longitud que la especie Gentoo, y la misma profundidad que la especie Adelie, por lo que no se podrían distinguir sin la etiqueta de especie
