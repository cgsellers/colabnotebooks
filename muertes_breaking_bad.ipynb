# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('deaths.csv')
df
# Out:
#     death_id                           death  \
# 0          1                   Emilio Koyama
# 1          2                         Krazy-8
# 2          3                         No-Doze
# 3          4                           Gonzo
# 4          5                  Tuco Salamanca
# ..       ...                             ...
# 60        61  White Supremacist gang members
# 61        62                    Todd Alquist
# 62        63                     Jack Welker
# 63        64            Lydia Rodarte-Quayle
# 64        65                    Walter White
#
#                                     cause                     responsible  \
# 0              Poisoned by phosphine gas.                    Walter White
# 1             Strangled with a bike lock.                    Walter White
# 2                        Beaten to death.                  Tuco Salamanca
# 3          Crushed under car in junkyard.                Accidental Death
# ...

# %%
len(df['responsible'].unique())
# Out:
# 36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   death_id          65 non-null     int64
#  1   death             65 non-null     object
#  2   cause             65 non-null     object
#  3   responsible       65 non-null     object
#  4   last_words        65 non-null     object
#  5   season            65 non-null     int64
#  6   episode           65 non-null     int64
#  7   number_of_deaths  65 non-null     int64
# dtypes: int64(4), object(4)
# memory usage: 4.2+ KB
